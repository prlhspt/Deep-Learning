# %% [markdown]
# # Dogs vs Cats v3
# ## Kaggle Dataset의 일부를 이용한 개, 고양이 구분
# ### Dog Image: 1,111개, Cat Image: 1,111개, 총 2,222개
# #### One-hot encoding --> Logistic Regression
# #### Data shuffling
# #### Early Stopping 제거
# ### 출처: [pontoregende GitHub](https://github.com/pontorezende/Dogs-vs-Cats-Redux-with-CNN)

# %%
import numpy as np
from glob import glob
import cv2, os, random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing import image
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Dense, Flatten, Dropout
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping
# Out:
# Using TensorFlow backend.

# %%
# seed 값 설정
seed = 2020
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
path='dogs-vs-cats/train/'

# %% [markdown]
# ### Train set 만들기

# %%
## used for resize and in our model
ROW, COL = 96, 96

dogs, cats = [], []
y_dogs, y_cats = [], []

# %%
dog_path = os.path.join(path, 'dog.5*')
len(glob(dog_path))
# Out:
# 1111

# %%
## Load some our dog images (1,111 개 이미지)
dog_path = os.path.join(path, 'dog.5*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
    dog = cv2.resize(dog, (ROW, COL))
    dog = image.img_to_array(dog)
    dogs.append(dog)

# %%
## Load some our cat images (1,111 개 이미지)
cat_path = os.path.join(path, 'cat.5*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    cats.append(cat)

# %%
classes = ['dog', 'cat']

# %%
plt.figure(figsize=(12,8))    
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(dogs))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[0]))        
plt.show()

# %%
plt.figure(figsize=(12,8))
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(cats))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[1]))
plt.show()

# %%
## just change the labels for 0 and  1
y_dogs = [1 for item in enumerate(dogs)]
y_cats = [0 for item in enumerate(cats)]

# %%
y_dogs[0], y_cats[0]
# Out:
# (1, 0)

# %%
## converting everything to Numpy array to fit in our model
## them creating a X and target file like we used to see
## in Machine and Deep Learning models
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
X_train = np.concatenate((dogs, cats), axis=0)
y_train = np.concatenate((y_dogs, y_cats), axis=0)

# %%
X_train.shape, y_train.shape
# Out:
# ((2222, 96, 96, 1), (2222,))

# %% [markdown]
# ### Test set (dog.12*, cat.12*) 만들기

# %%
dogs, cats = [], []
y_dogs, y_cats = [], []

# %%
dog_path = os.path.join(path, 'dog.12*')
len(glob(dog_path))
# Out:
# 611

# %%
## Load some our dog images (611 개 이미지)
dog_path = os.path.join(path, 'dog.12*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
    dog = cv2.resize(dog, (ROW, COL))
    dog = image.img_to_array(dog)
    dogs.append(dog)

# %%
## Load some our cat images (611 개 이미지)
cat_path = os.path.join(path, 'cat.12*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    cats.append(cat)

# %%
## just change the labels for 0 and  1
y_dogs = [1 for item in enumerate(dogs)]
y_cats = [0 for item in enumerate(cats)]

# %%
## converting everything to Numpy array to fit in our model
## them creating a X and target file like we used to see
## in Machine and Deep Learning models
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
X_test = np.concatenate((dogs, cats), axis=0)
y_test = np.concatenate((y_dogs, y_cats), axis=0)

# %%
X_test.shape, y_test.shape
# Out:
# ((1222, 96, 96, 1), (1222,))

# %% [markdown]
# ### 모델 설정

# %%
## Here is our model as a CNN
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(ROW, COL, 1), 
           activation='relu'),
    Conv2D(32, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(.5),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 96, 96, 32)        320
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 96, 96, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 48, 48, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 48, 48, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 48, 48, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 36864)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               18874880
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 18,940,385
# Trainable params: 18,940,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', 
              optimizer=Adam(), metrics=['accuracy'])

# %%
## to save checkpoint to use later
modelpath = "model/dogs_vs_cats-cnn3-{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', 
                               verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', 
                                        patience=10)

# %% [markdown]
# ### 모델 학습

# %%
model.fit(X_train, y_train, batch_size=32, epochs=40, 
          validation_split=0.2, shuffle=True,
          callbacks=[checkpointer])
# Out:
# Train on 1777 samples, validate on 445 samples
# Epoch 1/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.7063 - accuracy: 0.6095 - val_loss: 0.9693 - val_accuracy: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 0.96933, saving model to model/dogs_vs_cats-cnn3-01-0.9693.hdf5
# Epoch 2/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.6558 - accuracy: 0.6252 - val_loss: 0.8369 - val_accuracy: 0.0000e+00
#
# Epoch 00002: val_loss improved from 0.96933 to 0.83694, saving model to model/dogs_vs_cats-cnn3-02-0.8369.hdf5
# Epoch 3/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.6566 - accuracy: 0.6258 - val_loss: 0.8537 - val_accuracy: 0.0607
#
# Epoch 00003: val_loss did not improve from 0.83694
# Epoch 4/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.6312 - accuracy: 0.6415 - val_loss: 0.8443 - val_accuracy: 0.2539
#
# Epoch 00004: val_loss did not improve from 0.83694
# Epoch 5/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.5852 - accuracy: 0.6860 - val_loss: 0.6702 - val_accuracy: 0.5191
#
# Epoch 00005: val_loss improved from 0.83694 to 0.67021, saving model to model/dogs_vs_cats-cnn3-05-0.6702.hdf5
# Epoch 6/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.5672 - accuracy: 0.7107 - val_loss: 0.8263 - val_accuracy: 0.4360
#
# Epoch 00006: val_loss did not improve from 0.67021
# Epoch 7/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.5044 - accuracy: 0.7693 - val_loss: 0.9812 - val_accuracy: 0.4539
#
# Epoch 00007: val_loss did not improve from 0.67021
# Epoch 8/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.4476 - accuracy: 0.7867 - val_loss: 1.1646 - val_accuracy: 0.4000
#
# Epoch 00008: val_loss did not improve from 0.67021
# Epoch 9/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.4008 - accuracy: 0.8233 - val_loss: 0.7261 - val_accuracy: 0.6000
#
# Epoch 00009: val_loss did not improve from 0.67021
# Epoch 10/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.3287 - accuracy: 0.8593 - val_loss: 1.4032 - val_accuracy: 0.4809
#
# Epoch 00010: val_loss did not improve from 0.67021
# Epoch 11/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.2389 - accuracy: 0.8993 - val_loss: 1.2321 - val_accuracy: 0.5281
#
# Epoch 00011: val_loss did not improve from 0.67021
# Epoch 12/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.1706 - accuracy: 0.9297 - val_loss: 1.6497 - val_accuracy: 0.5213
#
# Epoch 00012: val_loss did not improve from 0.67021
# Epoch 13/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.1325 - accuracy: 0.9499 - val_loss: 1.4345 - val_accuracy: 0.6090
#
# Epoch 00013: val_loss did not improve from 0.67021
# Epoch 14/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.1044 - accuracy: 0.9600 - val_loss: 1.9568 - val_accuracy: 0.5551
#
# Epoch 00014: val_loss did not improve from 0.67021
# Epoch 15/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.0559 - accuracy: 0.9797 - val_loss: 2.1252 - val_accuracy: 0.5685
#
# Epoch 00015: val_loss did not improve from 0.67021
# Epoch 16/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.0405 - accuracy: 0.9882 - val_loss: 2.1827 - val_accuracy: 0.6225
#
# Epoch 00016: val_loss did not improve from 0.67021
# Epoch 17/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.0588 - accuracy: 0.9786 - val_loss: 1.9536 - val_accuracy: 0.5708
#
# Epoch 00017: val_loss did not improve from 0.67021
# Epoch 18/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.0473 - accuracy: 0.9865 - val_loss: 1.6942 - val_accuracy: 0.6539
#
# Epoch 00018: val_loss did not improve from 0.67021
# Epoch 19/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.0425 - accuracy: 0.9854 - val_loss: 2.0937 - val_accuracy: 0.5955
#
# Epoch 00019: val_loss did not improve from 0.67021
# Epoch 20/40
# 1777/1777 [==============================] - 36s 21ms/step - loss: 0.0353 - accuracy: 0.9887 - val_loss: 2.0807 - val_accuracy: 0.5865
#
# Epoch 00020: val_loss did not improve from 0.67021
# Epoch 21/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.0310 - accuracy: 0.9899 - val_loss: 2.3071 - val_accuracy: 0.5978
#
# Epoch 00021: val_loss did not improve from 0.67021
# Epoch 22/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.0142 - accuracy: 0.9961 - val_loss: 2.5625 - val_accuracy: 0.6090
#
# Epoch 00022: val_loss did not improve from 0.67021
# Epoch 23/40
# 1777/1777 [==============================] - 36s 21ms/step - loss: 0.0237 - accuracy: 0.9916 - val_loss: 1.9767 - val_accuracy: 0.6270
#
# Epoch 00023: val_loss did not improve from 0.67021
# Epoch 24/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.0177 - accuracy: 0.9961 - val_loss: 2.8392 - val_accuracy: 0.5326
#
# Epoch 00024: val_loss did not improve from 0.67021
# Epoch 25/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.0139 - accuracy: 0.9944 - val_loss: 2.7941 - val_accuracy: 0.5888
#
# Epoch 00025: val_loss did not improve from 0.67021
# Epoch 26/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.0117 - accuracy: 0.9961 - val_loss: 3.1994 - val_accuracy: 0.5775
#
# Epoch 00026: val_loss did not improve from 0.67021
# Epoch 27/40
# 1777/1777 [==============================] - 36s 21ms/step - loss: 0.0318 - accuracy: 0.9876 - val_loss: 2.4661 - val_accuracy: 0.6045
#
# Epoch 00027: val_loss did not improve from 0.67021
# Epoch 28/40
# 1777/1777 [==============================] - 36s 21ms/step - loss: 0.0134 - accuracy: 0.9955 - val_loss: 2.1019 - val_accuracy: 0.6360
#
# Epoch 00028: val_loss did not improve from 0.67021
# Epoch 29/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.0139 - accuracy: 0.9955 - val_loss: 2.7217 - val_accuracy: 0.5820
#
# Epoch 00029: val_loss did not improve from 0.67021
# Epoch 30/40
# 1777/1777 [==============================] - 36s 21ms/step - loss: 0.0173 - accuracy: 0.9955 - val_loss: 2.1882 - val_accuracy: 0.6517
#
# Epoch 00030: val_loss did not improve from 0.67021
# Epoch 31/40
# 1777/1777 [==============================] - 36s 21ms/step - loss: 0.0094 - accuracy: 0.9977 - val_loss: 2.0242 - val_accuracy: 0.6854
#
# Epoch 00031: val_loss did not improve from 0.67021
# Epoch 32/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.0116 - accuracy: 0.9961 - val_loss: 2.6780 - val_accuracy: 0.6112
#
# Epoch 00032: val_loss did not improve from 0.67021
# Epoch 33/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.0222 - accuracy: 0.9932 - val_loss: 3.8811 - val_accuracy: 0.4831
#
# Epoch 00033: val_loss did not improve from 0.67021
# Epoch 34/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.0476 - accuracy: 0.9893 - val_loss: 1.5869 - val_accuracy: 0.6652
#
# Epoch 00034: val_loss did not improve from 0.67021
# Epoch 35/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.0343 - accuracy: 0.9871 - val_loss: 1.7242 - val_accuracy: 0.6584
#
# Epoch 00035: val_loss did not improve from 0.67021
# Epoch 36/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.0105 - accuracy: 0.9977 - val_loss: 2.2243 - val_accuracy: 0.6225
#
# Epoch 00036: val_loss did not improve from 0.67021
# Epoch 37/40
# 1777/1777 [==============================] - 36s 21ms/step - loss: 0.0096 - accuracy: 0.9961 - val_loss: 2.6935 - val_accuracy: 0.5798
#
# Epoch 00037: val_loss did not improve from 0.67021
# Epoch 38/40
# 1777/1777 [==============================] - 36s 21ms/step - loss: 0.0073 - accuracy: 0.9989 - val_loss: 2.9767 - val_accuracy: 0.5573
#
# Epoch 00038: val_loss did not improve from 0.67021
# Epoch 39/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.0084 - accuracy: 0.9983 - val_loss: 2.2868 - val_accuracy: 0.6449
#
# Epoch 00039: val_loss did not improve from 0.67021
# Epoch 40/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.0180 - accuracy: 0.9949 - val_loss: 3.3702 - val_accuracy: 0.5079
#
# Epoch 00040: val_loss did not improve from 0.67021

# %%
from keras.models import load_model
del model
model = load_model('model/dogs_vs_cats-cnn3-05-0.6702.hdf5')

# %%
scores = model.evaluate(X_test, y_test, verbose=2)
print('MODEL ACCURACY: %.4f' % scores[1])
# Out:
# MODEL ACCURACY: 0.6105
