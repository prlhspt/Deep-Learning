# %% [markdown]
# # Dogs vs Cats
# ## Kaggle Dataset의 일부를 이용한 개, 고양이 구분
# ### Dog Image: 1,111개, Cat Image: 1,111개, 총 2,222개
# ### 출처: [pontoregende GitHub](https://github.com/pontorezende/Dogs-vs-Cats-Redux-with-CNN)

# %%
import numpy as np
from glob import glob
import cv2, os, random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing import image
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Dense, Flatten, Dropout
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping
# Out:
# Using TensorFlow backend.

# %%
# seed 값 설정
seed = 2020
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
path='dogs-vs-cats/train/'

# %% [markdown]
# ### Train set 만들기

# %%
## used for resize and in our model
ROW, COL = 96, 96

dogs, cats = [], []
y_dogs, y_cats = [], []

# %%
dog_path = os.path.join(path, 'dog.5*')
len(glob(dog_path))
# Out:
# 1111

# %%
## Load some our dog images (1,111 개 이미지)
dog_path = os.path.join(path, 'dog.5*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
    dog = cv2.resize(dog, (ROW, COL))
    dog = image.img_to_array(dog)
    dogs.append(dog)

# %%
## Load some our cat images (1,111 개 이미지)
cat_path = os.path.join(path, 'cat.5*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    cats.append(cat)

# %%
classes = ['dog', 'cat']

# %%
plt.figure(figsize=(12,8))    
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(dogs))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[0]))        
plt.show()

# %%
plt.figure(figsize=(12,8))
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(cats))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[1]))
plt.show()

# %%
## just change the labels for 0 and  1
y_dogs = [1 for item in enumerate(dogs)]
y_cats = [0 for item in enumerate(cats)]

# %%
y_dogs[0], y_cats[0]
# Out:
# (1, 0)

# %%
## converting everything to Numpy array to fit in our model
## them creating a X and target file like we used to see
## in Machine and Deep Learning models
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
X_train = np.concatenate((dogs, cats), axis=0)
y_train = np.concatenate((y_dogs, y_cats), axis=0)

# %%
len(X_train)
# Out:
# 2222

# %%
## One-Hot Encoding
y_train = keras.utils.to_categorical(y_train, 2)

# %% [markdown]
# ### Test set (dog.12*, cat.12*) 만들기

# %%
dogs, cats = [], []
y_dogs, y_cats = [], []

# %%
dog_path = os.path.join(path, 'dog.12*')
len(glob(dog_path))
# Out:
# 611

# %%
## Load some our dog images (611 개 이미지)
dog_path = os.path.join(path, 'dog.12*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
    dog = cv2.resize(dog, (ROW, COL))
    dog = image.img_to_array(dog)
    dogs.append(dog)

# %%
## Load some our cat images (611 개 이미지)
cat_path = os.path.join(path, 'cat.12*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    cats.append(cat)

# %%
## just change the labels for 0 and  1
y_dogs = [1 for item in enumerate(dogs)]
y_cats = [0 for item in enumerate(cats)]

# %%
## converting everything to Numpy array to fit in our model
## them creating a X and target file like we used to see
## in Machine and Deep Learning models
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
dogs.shape
# Out:
# (611, 96, 96, 1)

# %%
X_test = np.concatenate((dogs, cats), axis=0)
y_test = np.concatenate((y_dogs, y_cats), axis=0)

# %%
len(X_test)
# Out:
# 1222

# %%
## One-Hot Encoding
y_test = keras.utils.to_categorical(y_test, 2)

# %% [markdown]
# ### 모델 설정

# %%
## Here is our model as a CNN
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(ROW, COL, 1), 
           activation='relu'),
    Conv2D(32, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(.5),
    Dense(2, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 96, 96, 32)        320
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 96, 96, 32)        9248
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 48, 48, 32)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 48, 48, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 48, 48, 64)        36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 36864)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               18874880
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 18,940,898
# Trainable params: 18,940,898
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', 
              optimizer=Adam(), metrics=['accuracy'])

# %%
## to save checkpoint to use later
modelpath = "model/dogs_vs_cats-cnn-{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', 
                               verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', 
                                        patience=10)

# %% [markdown]
# ### 모델 학습

# %%
X_train.shape
# Out:
# (2222, 96, 96, 1)

# %%
model.fit(X_train, y_train, batch_size=32, epochs=40, 
          validation_split=0.2,
          callbacks=[checkpointer, early_stopping_callback])
# Out:
# Train on 1777 samples, validate on 445 samples
# Epoch 1/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.7504 - accuracy: 0.6083 - val_loss: 0.9770 - val_accuracy: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 0.97703, saving model to model/dogs_vs_cats-cnn-01-0.9770.hdf5
# Epoch 2/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.6596 - accuracy: 0.6252 - val_loss: 0.8665 - val_accuracy: 0.0000e+00
#
# Epoch 00002: val_loss improved from 0.97703 to 0.86649, saving model to model/dogs_vs_cats-cnn-02-0.8665.hdf5
# Epoch 3/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.6526 - accuracy: 0.6297 - val_loss: 0.8055 - val_accuracy: 0.2270
#
# Epoch 00003: val_loss improved from 0.86649 to 0.80553, saving model to model/dogs_vs_cats-cnn-03-0.8055.hdf5
# Epoch 4/40
# 1777/1777 [==============================] - 38s 21ms/step - loss: 0.6396 - accuracy: 0.6455 - val_loss: 0.9660 - val_accuracy: 0.2090
#
# Epoch 00004: val_loss did not improve from 0.80553
# Epoch 5/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.6347 - accuracy: 0.6624 - val_loss: 0.7832 - val_accuracy: 0.3011
#
# Epoch 00005: val_loss improved from 0.80553 to 0.78320, saving model to model/dogs_vs_cats-cnn-05-0.7832.hdf5
# Epoch 6/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.6224 - accuracy: 0.6730 - val_loss: 0.7064 - val_accuracy: 0.4225
#
# Epoch 00006: val_loss improved from 0.78320 to 0.70643, saving model to model/dogs_vs_cats-cnn-06-0.7064.hdf5
# Epoch 7/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.6161 - accuracy: 0.6742 - val_loss: 0.8013 - val_accuracy: 0.2944
#
# Epoch 00007: val_loss did not improve from 0.70643
# Epoch 8/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.5592 - accuracy: 0.7231 - val_loss: 1.0183 - val_accuracy: 0.3146
#
# Epoch 00008: val_loss did not improve from 0.70643
# Epoch 9/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.5297 - accuracy: 0.7507 - val_loss: 0.9678 - val_accuracy: 0.2337
#
# Epoch 00009: val_loss did not improve from 0.70643
# Epoch 10/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.4604 - accuracy: 0.7721 - val_loss: 0.9634 - val_accuracy: 0.4562
#
# Epoch 00010: val_loss did not improve from 0.70643
# Epoch 11/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.3606 - accuracy: 0.8424 - val_loss: 0.8642 - val_accuracy: 0.5708
#
# Epoch 00011: val_loss did not improve from 0.70643
# Epoch 12/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.2813 - accuracy: 0.8863 - val_loss: 0.9229 - val_accuracy: 0.6090
#
# Epoch 00012: val_loss did not improve from 0.70643
# Epoch 13/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.1922 - accuracy: 0.9257 - val_loss: 1.2733 - val_accuracy: 0.5730
#
# Epoch 00013: val_loss did not improve from 0.70643
# Epoch 14/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.1524 - accuracy: 0.9387 - val_loss: 1.5653 - val_accuracy: 0.5775
#
# Epoch 00014: val_loss did not improve from 0.70643
# Epoch 15/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.0859 - accuracy: 0.9696 - val_loss: 1.8575 - val_accuracy: 0.5371
#
# Epoch 00015: val_loss did not improve from 0.70643
# Epoch 16/40
# 1777/1777 [==============================] - 37s 21ms/step - loss: 0.0706 - accuracy: 0.9758 - val_loss: 1.3941 - val_accuracy: 0.6247
#
# Epoch 00016: val_loss did not improve from 0.70643

# %%
from keras.models import load_model
del model
model = load_model('model/dogs_vs_cats-cnn-06-0.7064.hdf5')

# %%
scores = model.evaluate(X_test, y_test, verbose=2)
print('MODEL ACCURACY: %.4f' % scores[1])
# Out:
# MODEL ACCURACY: 0.5745
