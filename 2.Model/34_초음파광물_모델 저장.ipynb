# %% [markdown]
# # 과적합 피하기 - 초음파광물 사례
# ## 학습셋과 테스트셋으로 구분
# ## 모델 저장과 재사용

# %%
import pandas as pd

df = pd.read_csv('../dataset/sonar.csv', header=None)
df.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# 3  0.0040  0.0117   R
# 4  0.0107  0.0094   R
#
# [5 rows x 61 columns]

# %%
import numpy as np
import tensorflow as tf

from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
# seed 값 설정
seed = 0
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
# 데이터 입력
dataset = df.values
X = np.array(dataset[:,0:60], dtype=np.float64)
Y_obj = dataset[:,60]

# %%
# 문자열 변환
e = LabelEncoder().fit(Y_obj)
Y = np.array(e.transform(Y_obj), dtype=np.float64)

# %%
# 학습셋과 테스트셋의 구분
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, 
                                                    random_state=seed)

# %%
# 모델 설정
model = Sequential([
    Dense(24, input_dim=60, activation='relu'),
    Dense(10, activation='relu'),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 24)                1464
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                250
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 1,725
# Trainable params: 1,725
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델 컴파일 
model.compile(loss='binary_crossentropy',   # mean_squared_error
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.fit(X_train, Y_train, epochs=130, batch_size=5)
# Out:
# Train on 145 samples
# Epoch 1/130
# 145/145 [==============================] - 0s 2ms/sample - loss: 0.6914 - accuracy: 0.4828
# Epoch 2/130
# 145/145 [==============================] - 0s 131us/sample - loss: 0.6639 - accuracy: 0.6207
# Epoch 3/130
# 145/145 [==============================] - 0s 138us/sample - loss: 0.6378 - accuracy: 0.6690
# Epoch 4/130
# 145/145 [==============================] - 0s 137us/sample - loss: 0.6161 - accuracy: 0.7379
# Epoch 5/130
# 145/145 [==============================] - 0s 151us/sample - loss: 0.5988 - accuracy: 0.7448
# Epoch 6/130
# 145/145 [==============================] - 0s 152us/sample - loss: 0.5861 - accuracy: 0.7517
# Epoch 7/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.5600 - accuracy: 0.7793
# Epoch 8/130
# 145/145 [==============================] - 0s 145us/sample - loss: 0.5511 - accuracy: 0.7310
# Epoch 9/130
# 145/145 [==============================] - 0s 138us/sample - loss: 0.5302 - accuracy: 0.7931
# Epoch 10/130
# 145/145 [==============================] - 0s 131us/sample - loss: 0.5103 - accuracy: 0.7931
# Epoch 11/130
# 145/145 [==============================] - 0s 131us/sample - loss: 0.4980 - accuracy: 0.7793
# Epoch 12/130
# 145/145 [==============================] - 0s 131us/sample - loss: 0.4782 - accuracy: 0.7793
# Epoch 13/130
# 145/145 [==============================] - 0s 131us/sample - loss: 0.4704 - accuracy: 0.8207
# Epoch 14/130
# 145/145 [==============================] - 0s 131us/sample - loss: 0.4599 - accuracy: 0.7931
# Epoch 15/130
# 145/145 [==============================] - 0s 124us/sample - loss: 0.4461 - accuracy: 0.8414
# Epoch 16/130
# 145/145 [==============================] - 0s 131us/sample - loss: 0.4456 - accuracy: 0.8414
# Epoch 17/130
# 145/145 [==============================] - 0s 131us/sample - loss: 0.4451 - accuracy: 0.8000
# Epoch 18/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.4253 - accuracy: 0.8414
# Epoch 19/130
# 145/145 [==============================] - 0s 138us/sample - loss: 0.4187 - accuracy: 0.8069
# Epoch 20/130
# 145/145 [==============================] - 0s 151us/sample - loss: 0.4051 - accuracy: 0.8276
# Epoch 21/130
# 145/145 [==============================] - 0s 151us/sample - loss: 0.4010 - accuracy: 0.8345
# Epoch 22/130
# 145/145 [==============================] - 0s 145us/sample - loss: 0.4208 - accuracy: 0.8138
# Epoch 23/130
# 145/145 [==============================] - 0s 138us/sample - loss: 0.3837 - accuracy: 0.8690
# Epoch 24/130
# 145/145 [==============================] - 0s 145us/sample - loss: 0.3821 - accuracy: 0.8138
# Epoch 25/130
# 145/145 [==============================] - 0s 158us/sample - loss: 0.3763 - accuracy: 0.8483
# Epoch 26/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.3657 - accuracy: 0.8621
# Epoch 27/130
# 145/145 [==============================] - ETA: 0s - loss: 0.5463 - accuracy: 0.60 - 0s 151us/sample - loss: 0.3605 - accuracy: 0.8483
# Epoch 28/130
# 145/145 [==============================] - 0s 151us/sample - loss: 0.3665 - accuracy: 0.8276
# Epoch 29/130
# 145/145 [==============================] - 0s 151us/sample - loss: 0.3495 - accuracy: 0.8621
# Epoch 30/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.3445 - accuracy: 0.8690
# Epoch 31/130
# 145/145 [==============================] - 0s 158us/sample - loss: 0.3410 - accuracy: 0.8759
# Epoch 32/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.3538 - accuracy: 0.8690
# Epoch 33/130
# 145/145 [==============================] - 0s 151us/sample - loss: 0.3327 - accuracy: 0.8897
# Epoch 34/130
# 145/145 [==============================] - 0s 151us/sample - loss: 0.3320 - accuracy: 0.8621
# Epoch 35/130
# 145/145 [==============================] - 0s 138us/sample - loss: 0.3179 - accuracy: 0.8828
# Epoch 36/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.3143 - accuracy: 0.8759
# Epoch 37/130
# 145/145 [==============================] - 0s 151us/sample - loss: 0.3216 - accuracy: 0.8759
# Epoch 38/130
# 145/145 [==============================] - 0s 145us/sample - loss: 0.3076 - accuracy: 0.8759
# Epoch 39/130
# 145/145 [==============================] - 0s 151us/sample - loss: 0.3099 - accuracy: 0.8690
# Epoch 40/130
# 145/145 [==============================] - 0s 172us/sample - loss: 0.2987 - accuracy: 0.8759
# Epoch 41/130
# 145/145 [==============================] - 0s 158us/sample - loss: 0.2973 - accuracy: 0.8690
# Epoch 42/130
# 145/145 [==============================] - 0s 151us/sample - loss: 0.2989 - accuracy: 0.8621
# Epoch 43/130
# 145/145 [==============================] - 0s 151us/sample - loss: 0.2939 - accuracy: 0.8828
# Epoch 44/130
# 145/145 [==============================] - 0s 151us/sample - loss: 0.2840 - accuracy: 0.8897
# Epoch 45/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.2928 - accuracy: 0.8690
# Epoch 46/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.3085 - accuracy: 0.8621
# Epoch 47/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.2749 - accuracy: 0.8690
# Epoch 48/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.2764 - accuracy: 0.8690
# Epoch 49/130
# 145/145 [==============================] - 0s 138us/sample - loss: 0.2711 - accuracy: 0.8828
# Epoch 50/130
# 145/145 [==============================] - 0s 137us/sample - loss: 0.2609 - accuracy: 0.8897
# Epoch 51/130
# 145/145 [==============================] - 0s 145us/sample - loss: 0.2601 - accuracy: 0.8966
# Epoch 52/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.2546 - accuracy: 0.8897
# Epoch 53/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.2517 - accuracy: 0.8897
# Epoch 54/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.2460 - accuracy: 0.8966
# Epoch 55/130
# 145/145 [==============================] - 0s 137us/sample - loss: 0.2435 - accuracy: 0.8966
# Epoch 56/130
# 145/145 [==============================] - 0s 151us/sample - loss: 0.2359 - accuracy: 0.9034
# Epoch 57/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.2390 - accuracy: 0.9103
# Epoch 58/130
# 145/145 [==============================] - 0s 151us/sample - loss: 0.2285 - accuracy: 0.9103
# Epoch 59/130
# 145/145 [==============================] - 0s 151us/sample - loss: 0.2268 - accuracy: 0.8966
# Epoch 60/130
# 145/145 [==============================] - 0s 151us/sample - loss: 0.2263 - accuracy: 0.9103
# Epoch 61/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.2209 - accuracy: 0.9103
# Epoch 62/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.2223 - accuracy: 0.8966
# Epoch 63/130
# 145/145 [==============================] - 0s 151us/sample - loss: 0.2173 - accuracy: 0.9034
# Epoch 64/130
# 145/145 [==============================] - 0s 145us/sample - loss: 0.2082 - accuracy: 0.9241
# Epoch 65/130
# 145/145 [==============================] - 0s 138us/sample - loss: 0.2027 - accuracy: 0.9172
# Epoch 66/130
# 145/145 [==============================] - 0s 138us/sample - loss: 0.2098 - accuracy: 0.9034
# Epoch 67/130
# 145/145 [==============================] - 0s 138us/sample - loss: 0.1999 - accuracy: 0.9241
# Epoch 68/130
# 145/145 [==============================] - 0s 138us/sample - loss: 0.1981 - accuracy: 0.9172
# Epoch 69/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.1950 - accuracy: 0.9172
# Epoch 70/130
# 145/145 [==============================] - 0s 138us/sample - loss: 0.2024 - accuracy: 0.9172
# Epoch 71/130
# 145/145 [==============================] - 0s 131us/sample - loss: 0.2151 - accuracy: 0.9034
# Epoch 72/130
# 145/145 [==============================] - ETA: 0s - loss: 0.1528 - accuracy: 1.00 - 0s 138us/sample - loss: 0.1828 - accuracy: 0.9310
# Epoch 73/130
# 145/145 [==============================] - 0s 138us/sample - loss: 0.1768 - accuracy: 0.9241
# Epoch 74/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.1802 - accuracy: 0.9379
# Epoch 75/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.1735 - accuracy: 0.9172
# Epoch 76/130
# 145/145 [==============================] - 0s 137us/sample - loss: 0.1740 - accuracy: 0.9310
# Epoch 77/130
# 145/145 [==============================] - 0s 152us/sample - loss: 0.1860 - accuracy: 0.9379
# Epoch 78/130
# 145/145 [==============================] - 0s 151us/sample - loss: 0.1621 - accuracy: 0.9379
# Epoch 79/130
# 145/145 [==============================] - 0s 152us/sample - loss: 0.1700 - accuracy: 0.9379
# Epoch 80/130
# 145/145 [==============================] - 0s 138us/sample - loss: 0.1670 - accuracy: 0.9241
# Epoch 81/130
# 145/145 [==============================] - 0s 124us/sample - loss: 0.1554 - accuracy: 0.9517
# Epoch 82/130
# 145/145 [==============================] - 0s 131us/sample - loss: 0.1592 - accuracy: 0.9310
# Epoch 83/130
# 145/145 [==============================] - 0s 138us/sample - loss: 0.1580 - accuracy: 0.9517
# Epoch 84/130
# 145/145 [==============================] - 0s 138us/sample - loss: 0.1738 - accuracy: 0.9172
# Epoch 85/130
# 145/145 [==============================] - 0s 138us/sample - loss: 0.1513 - accuracy: 0.9310
# Epoch 86/130
# 145/145 [==============================] - 0s 131us/sample - loss: 0.1451 - accuracy: 0.9517
# Epoch 87/130
# 145/145 [==============================] - 0s 138us/sample - loss: 0.1419 - accuracy: 0.9517
# Epoch 88/130
# 145/145 [==============================] - 0s 138us/sample - loss: 0.1333 - accuracy: 0.9586
# Epoch 89/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.1460 - accuracy: 0.9448
# Epoch 90/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.1395 - accuracy: 0.9586
# Epoch 91/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.1336 - accuracy: 0.9517
# Epoch 92/130
# 145/145 [==============================] - 0s 131us/sample - loss: 0.1321 - accuracy: 0.9448
# Epoch 93/130
# 145/145 [==============================] - 0s 138us/sample - loss: 0.1284 - accuracy: 0.9655
# Epoch 94/130
# 145/145 [==============================] - 0s 138us/sample - loss: 0.1243 - accuracy: 0.9655
# Epoch 95/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.1143 - accuracy: 0.9655
# Epoch 96/130
# 145/145 [==============================] - 0s 145us/sample - loss: 0.1287 - accuracy: 0.9655
# Epoch 97/130
# 145/145 [==============================] - 0s 158us/sample - loss: 0.1141 - accuracy: 0.9724
# Epoch 98/130
# 145/145 [==============================] - 0s 151us/sample - loss: 0.1207 - accuracy: 0.9655
# Epoch 99/130
# 145/145 [==============================] - 0s 138us/sample - loss: 0.1029 - accuracy: 0.9931
# Epoch 100/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.1080 - accuracy: 0.9793
# Epoch 101/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.1049 - accuracy: 0.9862
# Epoch 102/130
# 145/145 [==============================] - 0s 138us/sample - loss: 0.1034 - accuracy: 0.9724
# Epoch 103/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.1043 - accuracy: 0.9793
# Epoch 104/130
# 145/145 [==============================] - 0s 138us/sample - loss: 0.1064 - accuracy: 0.9724
# Epoch 105/130
# 145/145 [==============================] - 0s 138us/sample - loss: 0.1065 - accuracy: 0.9931
# Epoch 106/130
# 145/145 [==============================] - 0s 137us/sample - loss: 0.0954 - accuracy: 0.9931
# Epoch 107/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.0971 - accuracy: 0.9793
# Epoch 108/130
# 145/145 [==============================] - 0s 151us/sample - loss: 0.0860 - accuracy: 0.9931
# Epoch 109/130
# 145/145 [==============================] - 0s 151us/sample - loss: 0.0919 - accuracy: 0.9724
# Epoch 110/130
# 145/145 [==============================] - 0s 151us/sample - loss: 0.1019 - accuracy: 0.9724
# Epoch 111/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.0840 - accuracy: 0.9862
# Epoch 112/130
# 145/145 [==============================] - 0s 151us/sample - loss: 0.0779 - accuracy: 0.9931
# Epoch 113/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.0751 - accuracy: 0.9931
# Epoch 114/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.0794 - accuracy: 0.9862
# Epoch 115/130
# 145/145 [==============================] - 0s 138us/sample - loss: 0.0763 - accuracy: 0.9931
# Epoch 116/130
# 145/145 [==============================] - 0s 131us/sample - loss: 0.0716 - accuracy: 0.9931
# Epoch 117/130
# 145/145 [==============================] - 0s 124us/sample - loss: 0.0745 - accuracy: 0.9793
# Epoch 118/130
# 145/145 [==============================] - 0s 117us/sample - loss: 0.0765 - accuracy: 0.9862
# Epoch 119/130
# 145/145 [==============================] - 0s 117us/sample - loss: 0.0643 - accuracy: 0.9931
# Epoch 120/130
# 145/145 [==============================] - 0s 138us/sample - loss: 0.0704 - accuracy: 1.0000
# Epoch 121/130
# 145/145 [==============================] - 0s 144us/sample - loss: 0.0699 - accuracy: 0.9931
# Epoch 122/130
# 145/145 [==============================] - 0s 138us/sample - loss: 0.0644 - accuracy: 1.0000
# Epoch 123/130
# 145/145 [==============================] - 0s 124us/sample - loss: 0.0640 - accuracy: 0.9931
# Epoch 124/130
# 145/145 [==============================] - 0s 131us/sample - loss: 0.0667 - accuracy: 1.0000
# Epoch 125/130
# 145/145 [==============================] - 0s 124us/sample - loss: 0.0590 - accuracy: 0.9862
# Epoch 126/130
# 145/145 [==============================] - 0s 124us/sample - loss: 0.0586 - accuracy: 1.0000
# Epoch 127/130
# 145/145 [==============================] - 0s 124us/sample - loss: 0.0568 - accuracy: 1.0000
# Epoch 128/130
# 145/145 [==============================] - 0s 117us/sample - loss: 0.0553 - accuracy: 1.0000
# Epoch 129/130
# 145/145 [==============================] - 0s 117us/sample - loss: 0.0637 - accuracy: 0.9862
# Epoch 130/130
# 145/145 [==============================] - 0s 124us/sample - loss: 0.0600 - accuracy: 0.9931

# %%
# 모델을 컴퓨터에 저장
model.save('model/my_model.h5')

# %%
del model       # 테스트를 위해 메모리 내의 모델을 삭제

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-5f15418b3570> in <module>
# ----> 1 model.summary()
#
# NameError: name 'model' is not defined

# %%
model = load_model('model/my_model.h5') # 모델을 새로 불러옴

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 24)                1464
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                250
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 1,725
# Trainable params: 1,725
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 테스트셋에 불러온 모델 적용 
print("\n Test Accuracy: %.4f" % (model.evaluate(X_test, Y_test, verbose=2) [1]))
# Out:
# 63/63 - 0s - loss: 0.6639 - accuracy: 0.8413
#
#  Test Accuracy: 0.8413

# %%
dir(model)
# Out:
# ['_TF_MODULE_IGNORED_PROPERTIES',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_activity_regularizer',
#  '_add_inbound_node',
#  '_add_trackable',
#  '_add_unique_metric_name',
#  '_add_variable_with_custom_getter',
#  '_assert_compile_was_called',
#  '_assert_weights_created',
#  '_attribute_sentinel',
#  '_autocast',
#  '_base_init',
#  '_build_input_shape',
#  '_build_model_with_inputs',
#  '_cache_output_metric_attributes',
#  '_call_accepts_kwargs',
#  '_call_arg_was_passed',
#  '_call_fn_args',
#  '_call_full_argspec',
#  '_callable_losses',
#  '_check_call_args',
#  '_check_trainable_weights_consistency',
#  '_checkpoint_dependencies',
#  '_clear_losses',
#  '_collect_input_masks',
#  '_collected_trainable_weights',
#  '_compile_distribution',
#  '_compile_eagerly',
#  '_compile_from_inputs',
#  '_compile_metric_functions',
#  '_compile_metrics',
#  '_compile_time_distribution_strategy',
#  '_compile_weighted_metrics',
#  '_compile_weights_loss_and_weighted_metrics',
#  '_compiled_trainable_state',
#  '_compute_dtype',
#  '_compute_output_and_mask_jointly',
#  '_dedup_weights',
#  '_deferred_dependencies',
#  '_distributed_function_cache',
#  '_distributed_model_cache',
#  '_distribution_standardize_user_data',
#  '_distribution_strategy',
#  '_dtype',
#  '_dtype_defaulted_to_floatx',
#  '_dtype_policy',
#  '_dynamic',
#  '_eager_add_metric',
#  '_eager_losses',
#  '_expects_mask_arg',
#  '_expects_training_arg',
#  '_experimental_run_tf_function',
#  '_feed_input_names',
#  '_feed_input_shapes',
#  '_feed_inputs',
#  '_feed_loss_fns',
#  '_feed_output_names',
#  '_feed_output_shapes',
#  '_feed_sample_weights',
#  '_feed_targets',
#  '_flatten',
#  '_function_kwargs',
#  '_gather_children_attribute',
#  '_gather_saveables_for_checkpoint',
#  '_get_call_arg_value',
#  '_get_callback_model',
#  '_get_distribution_strategy',
#  '_get_existing_metric',
#  '_get_node_attribute_at_index',
#  '_get_trainable_state',
#  '_get_training_eval_metrics',
#  '_graph',
#  '_graph_network_add_loss',
#  '_graph_network_add_metric',
#  '_handle_activity_regularization',
#  '_handle_deferred_dependencies',
#  '_handle_metrics',
#  '_handle_per_output_metrics',
#  '_handle_weight_regularization',
#  '_in_multi_worker_mode',
#  '_inbound_nodes',
#  '_init_call_fn_args',
#  '_init_distributed_function_cache_if_not_compiled',
#  '_init_graph_network',
#  '_init_metric_attributes',
#  '_init_set_name',
#  '_init_subclassed_network',
#  '_input_coordinates',
#  '_input_layers',
#  '_insert_layers',
#  '_is_compiled',
#  '_is_graph_network',
#  '_is_layer',
#  '_keras_api_names',
#  '_keras_api_names_v1',
#  '_layer_call_argspecs',
#  '_layers',
#  '_list_extra_dependencies_for_serialization',
#  '_list_functions_for_serialization',
#  '_lookup_dependency',
#  '_loss_weights_list',
#  '_losses',
#  '_make_callback_model',
#  '_make_execution_function',
#  '_make_predict_function',
#  '_make_test_function',
#  '_make_train_function',
#  '_maybe_build',
#  '_maybe_cast_inputs',
#  '_maybe_create_attribute',
#  '_maybe_initialize_trackable',
#  '_maybe_load_initial_epoch_from_ckpt',
#  '_metrics',
#  '_name',
#  '_name_based_attribute_restore',
#  '_name_based_restores',
#  '_name_scope',
#  '_nested_inputs',
#  '_nested_outputs',
#  '_network_nodes',
#  '_no_dependency',
#  '_nodes_by_depth',
#  '_non_trainable_weights',
#  '_obj_reference_counts',
#  '_obj_reference_counts_dict',
#  '_object_identifier',
#  '_outbound_nodes',
#  '_output_coordinates',
#  '_output_layers',
#  '_output_loss_metrics',
#  '_output_mask_cache',
#  '_output_shape_cache',
#  '_output_tensor_cache',
#  '_per_output_metrics',
#  '_per_output_weighted_metrics',
#  '_preload_simple_restoration',
#  '_prepare_output_masks',
#  '_prepare_sample_weights',
#  '_prepare_skip_target_masks',
#  '_prepare_total_loss',
#  '_prepare_validation_data',
#  '_process_target_tensor_for_compile',
#  '_recompile_weights_loss_and_weighted_metrics',
#  '_restore_from_checkpoint_position',
#  '_reuse',
#  '_run_eagerly',
#  '_run_internal_graph',
#  '_sample_weight_modes',
#  '_scope',
#  '_select_training_loop',
#  '_self_name_based_restores',
#  '_self_setattr_tracking',
#  '_self_unconditional_checkpoint_dependencies',
#  '_self_unconditional_deferred_dependencies',
#  '_self_unconditional_dependency_names',
#  '_self_update_uid',
#  '_set_connectivity_metadata_',
#  '_set_dtype_policy',
#  '_set_input_attrs',
#  '_set_inputs',
#  '_set_mask_metadata',
#  '_set_metric_attributes',
#  '_set_optimizer',
#  '_set_output_attrs',
#  '_set_output_names',
#  '_set_per_output_metric_attributes',
#  '_set_strategy',
#  '_set_trainable_state',
#  '_setattr_tracking',
#  '_should_compute_mask',
#  '_single_restoration_from_checkpoint_position',
#  '_standardize_tensors',
#  '_standardize_user_data',
#  '_successful_loop_finish',
#  '_supports_ragged_inputs',
#  '_symbolic_add_metric',
#  '_symbolic_call',
#  '_targets',
#  '_tf_api_names',
#  '_tf_api_names_v1',
#  '_thread_local',
#  '_track_layers',
#  '_track_trackable',
#  '_trackable_saved_model_saver',
#  '_trackable_saver',
#  '_tracking_metadata',
#  '_trainable',
#  '_trainable_weights',
#  '_training_endpoints',
#  '_unconditional_checkpoint_dependencies',
#  '_unconditional_dependency_names',
#  '_undeduplicated_weights',
#  '_update_sample_weight_modes',
#  '_update_uid',
#  '_updated_config',
#  '_updates',
#  '_validate_compile_param_for_distribution_strategy',
#  '_validate_graph_inputs_and_outputs',
#  '_validate_or_infer_batch_size',
#  '_warn_about_input_casting',
#  'activity_regularizer',
#  'add',
#  'add_loss',
#  'add_metric',
#  'add_update',
#  'add_variable',
#  'add_weight',
#  'apply',
#  'build',
#  'built',
#  'call',
#  'compile',
#  'compute_mask',
#  'compute_output_shape',
#  'compute_output_signature',
#  'count_params',
#  'dtype',
#  'dynamic',
#  'evaluate',
#  'evaluate_generator',
#  'fit',
#  'fit_generator',
#  'from_config',
#  'get_config',
#  'get_input_at',
#  'get_input_mask_at',
#  'get_input_shape_at',
#  'get_layer',
#  'get_losses_for',
#  'get_output_at',
#  'get_output_mask_at',
#  'get_output_shape_at',
#  'get_updates_for',
#  'get_weights',
#  'inbound_nodes',
#  'input',
#  'input_mask',
#  'input_names',
#  'input_shape',
#  'input_spec',
#  'inputs',
#  'layers',
#  'load_weights',
#  'loss',
#  'loss_functions',
#  'loss_weights',
#  'losses',
#  'metrics',
#  'metrics_names',
#  'name',
#  'name_scope',
#  'non_trainable_variables',
#  'non_trainable_weights',
#  'optimizer',
#  'outbound_nodes',
#  'output',
#  'output_mask',
#  'output_names',
#  'output_shape',
#  'outputs',
#  'pop',
#  'predict',
#  'predict_classes',
#  'predict_function',
#  'predict_generator',
#  'predict_on_batch',
#  'predict_proba',
#  'reset_metrics',
#  'reset_states',
#  'run_eagerly',
#  'sample_weight_mode',
#  'sample_weights',
#  'save',
#  'save_weights',
#  'set_weights',
#  'state_updates',
#  'stateful',
#  'stop_training',
#  'submodules',
#  'summary',
#  'supports_masking',
#  'test_function',
#  'test_on_batch',
#  'to_json',
#  'to_yaml',
#  'total_loss',
#  'train_function',
#  'train_on_batch',
#  'trainable',
#  'trainable_variables',
#  'trainable_weights',
#  'updates',
#  'variables',
#  'weights',
#  'with_name_scope']

# %%
model.weights
# Out:
# [<tf.Variable 'dense_3/kernel:0' shape=(60, 24) dtype=float32, numpy=
#  array([[ 0.12401541,  0.22524294,  0.518966  , ..., -0.46999693,
#           0.52779645, -0.18812777],
#         [ 0.3560194 ,  0.24210212,  0.43628225, ..., -0.38684186,
#           0.0242069 , -0.10510983],
#         [-0.18299909,  0.00269319,  0.07766257, ...,  0.17457959,
#          -0.1204645 ,  0.21940234],
#         ...,
#         [ 0.2439441 , -0.126234  , -0.26034033, ...,  0.2767162 ,
#          -0.00488428, -0.26783857],
#         [ 0.6027458 ,  0.62568444,  0.6283348 , ..., -0.44608542,
#           0.85664266, -0.647344  ],
#         [-0.14049426,  0.5966832 ,  0.52330655, ..., -0.37432232,
#           0.48396447, -0.47643095]], dtype=float32)>,
#  <tf.Variable 'dense_3/bias:0' shape=(24,) dtype=float32, numpy=
#  array([-0.0998541 , -0.10684478, -0.20313595,  0.        ,  0.        ,
#          0.0842314 , -0.01672909, -0.11843636,  0.        ,  0.        ,
#          0.11340952,  0.1600701 , -0.11113489, -0.12326199,  0.05769547,
#          0.2604914 ,  0.        ,  0.        , -0.05682371,  0.1615851 ,
#          0.18480946,  0.23782118, -0.09008738,  0.1644679 ], dtype=float32)>,
#  <tf.Variable 'dense_1_1/kernel:0' shape=(24, 10) dtype=float32, numpy=
#  array([[ 1.85288727e-01, -8.41006756e-01,  3.12356859e-01,
#          -7.04526156e-02,  1.21922404e-01,  3.42281699e-01,
#          -4.02832299e-01,  6.49428725e-01, -3.82130235e-01,
#          -3.63818228e-01],
#         [ 1.79125771e-01,  8.71024877e-02, -4.51317966e-01,
#          -1.66324098e-02, -3.29447210e-01,  7.28813231e-01,
#          -2.47701734e-01,  4.67303306e-01, -6.38296425e-01,
#          -5.81237972e-01],
#         [ 2.46454194e-01, -7.68528804e-02, -3.71247470e-01,
#          -5.73746681e-01, -3.78071517e-02,  1.10910070e+00,
#           3.38275522e-01,  9.56793606e-01, -5.01105428e-01,
#          -7.62335658e-01],
#         [-3.44451964e-02,  1.50167376e-01, -2.04437301e-01,
#           1.33132070e-01,  2.38682300e-01,  4.10483271e-01,
#          -2.38486469e-01, -4.05319661e-01, -7.53164291e-04,
#          -3.37953031e-01],
#         [ 3.93836468e-01,  2.99685270e-01,  3.00703555e-01,
#          -2.33819783e-02,  2.04284787e-02,  1.57652408e-01,
#           7.13814795e-02,  1.88596934e-01, -3.75869930e-01,
#          -2.23777279e-01],
#         [ 4.18132037e-01,  6.52999384e-04,  3.18609297e-01,
#           6.97298229e-01, -2.03776360e-01, -8.42937410e-01,
#           2.48099655e-01, -4.65292424e-01,  6.92569792e-01,
#           4.02621120e-01],
#         [ 1.87620342e-01, -1.31479979e-01, -5.14443517e-02,
#          -2.18830258e-01,  9.27503780e-02, -3.09234142e-01,
#          -1.09441243e-01,  3.92995119e-01,  3.09776902e-01,
#          -3.67732793e-01],
#         [-3.51826161e-01, -2.48030975e-01,  4.45297658e-02,
#          -4.39792067e-01, -1.65008649e-01,  3.49728286e-01,
#           6.80606067e-02,  3.23226839e-01,  2.04083830e-01,
#          -1.72873959e-01],
#         [-3.65447402e-01, -3.20312798e-01, -3.12909782e-01,
#          -3.81150961e-01, -2.08810404e-01, -2.99093276e-01,
#          -1.40352190e-01,  1.62925214e-01,  2.53681839e-02,
#           1.86744362e-01],
#         [ 2.47884721e-01, -2.36397415e-01, -2.84660339e-01,
#           3.50533217e-01, -2.69903451e-01,  1.84994429e-01,
#          -1.53435647e-01,  1.78643554e-01, -2.56996691e-01,
#          -3.95238578e-01],
#         [ 1.46431446e-01,  2.02656031e-01,  1.77535743e-01,
#           2.44094372e-01,  2.78580822e-02,  4.99988824e-01,
#          -3.14379156e-01,  4.42128509e-01,  8.20428506e-02,
#           1.91524953e-01],
#         [ 8.40188190e-03, -1.79165155e-01,  3.08350086e-01,
#          -1.05060196e+00, -3.28861892e-01,  9.25913751e-01,
#           3.46659988e-01,  5.73202908e-01, -7.66472518e-01,
#          -2.63786018e-01],
#         [-2.40052953e-01, -6.11688435e-01, -3.19057673e-01,
#          -7.82413110e-02, -2.52574593e-01,  4.61077154e-01,
#          -3.45112771e-01,  2.67498851e-01,  1.35269836e-01,
#          -4.43503499e-01],
#         [-2.80270696e-01,  3.46311957e-01,  8.86907429e-02,
#          -3.80580306e-01,  1.62605479e-01,  4.90078270e-01,
#          -1.98685393e-01,  1.17064245e-01, -6.08256638e-01,
#          -6.30733252e-01],
#         [ 7.44711697e-01, -3.50640476e-01, -2.08287627e-01,
#          -4.69543815e-01,  1.17682785e-01,  7.29633152e-01,
#           3.32481533e-01,  7.84457445e-01, -1.10969722e+00,
#          -1.28346884e+00],
#         [-1.55616209e-01, -4.64652389e-01,  3.20138395e-01,
#           1.24937665e+00, -3.00049067e-01, -1.40738165e+00,
#           3.97893608e-01, -1.54548383e+00,  1.70838559e+00,
#           1.08985102e+00],
#         [-8.74598920e-02,  2.66833991e-01, -2.14386776e-01,
#           1.97032899e-01,  2.33642459e-02, -1.90238595e-01,
#           4.36993837e-02, -7.85720646e-02,  4.00930732e-01,
#          -5.56172431e-02],
#         [ 1.81284875e-01, -2.23210812e-01, -5.09190261e-02,
#           3.56441885e-01,  1.45431161e-02,  3.74841660e-01,
#           1.69182450e-01, -4.08545375e-01, -1.82932436e-01,
#           4.62293327e-02],
#         [-2.91077286e-01, -3.93498465e-02, -1.89383715e-01,
#          -1.24230005e-01,  6.66695312e-02,  2.52762884e-01,
#          -9.36703663e-03,  3.67686570e-01, -7.37731382e-02,
#           1.66471243e-01],
#         [-2.38420710e-01,  1.51696214e-02, -1.39753595e-01,
#           3.38449448e-01, -2.02319305e-02, -6.18146241e-01,
#          -3.92525762e-01,  1.36963740e-01,  7.41714716e-01,
#           5.90088308e-01],
#         [ 2.89699137e-01, -2.53221039e-02,  2.85856217e-01,
#           2.32535496e-01, -3.33268255e-01, -5.28099597e-01,
#          -3.35733145e-01, -3.60710084e-01,  8.55980515e-01,
#           6.53904676e-01],
#         [-3.49215679e-02,  8.56148675e-02, -1.45420015e-01,
#           9.09256279e-01, -3.26744974e-01, -6.16073430e-01,
#           7.34375732e-04, -4.90368426e-01,  6.00013554e-01,
#           8.42484653e-01],
#         [ 3.97803873e-01,  4.36237693e-01, -2.95327574e-01,
#          -4.22724217e-01, -3.56288165e-01,  6.54706597e-01,
#          -3.92180622e-01, -1.02798976e-01, -4.09301460e-01,
#          -3.65637451e-01],
#         [-2.75240332e-01, -5.81715822e-01, -3.87459666e-01,
#           4.74407852e-01, -4.08179998e-01, -6.53226376e-02,
#          -3.82875204e-01,  1.52895793e-01,  1.26605123e-01,
#           3.96317780e-01]], dtype=float32)>,
#  <tf.Variable 'dense_1_1/bias:0' shape=(10,) dtype=float32, numpy=
#  array([-0.00493747,  0.20264198, -0.01920213,  0.11886334, -0.00547526,
#         -0.08213621,  0.00993341, -0.10513812,  0.2113743 ,  0.20921989],
#        dtype=float32)>,
#  <tf.Variable 'dense_2_1/kernel:0' shape=(10, 1) dtype=float32, numpy=
#  array([[-1.0896621 ],
#         [ 1.3555808 ],
#         [ 0.00227545],
#         [ 1.1325561 ],
#         [-0.1317397 ],
#         [-1.427085  ],
#         [ 0.3181418 ],
#         [-0.44938695],
#         [ 1.1240844 ],
#         [ 1.5317485 ]], dtype=float32)>,
#  <tf.Variable 'dense_2_1/bias:0' shape=(1,) dtype=float32, numpy=array([0.08735939], dtype=float32)>]

# %%
len(model.weights)
# Out:
# 6

# %%
for i in range(6):
    print(i, model.weights[i].shape)
# Out:
# 0 (60, 24)
# 1 (24,)
# 2 (24, 10)
# 3 (10,)
# 4 (10, 1)
# 5 (1,)
